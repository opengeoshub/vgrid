# %% [markdown]
# # Working with OLC in Vgrid DGGS
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeoshub/vgrid/blob/main/docs/notebooks/11_olc.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeoshub/vgrid/HEAD?filepath=docs/notebooks/11_olc.ipynb)
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeoshub/vgrid/blob/main/docs/notebooks/11_olc.ipynb)
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://jupyterlite.gishub.vn/lab/index.html?path=notebooks/vgrid/11_olc.ipynb)
#
# Full Vgrid DGGS documentation is available at [vgrid document](https://vgrid.gishub.vn).
#
# To work with Vgrid DGGS directly in GeoPandas and Pandas, please use [vgridpandas](https://pypi.org/project/vgridpandas/). Full Vgridpandas DGGS documentation is available at [vgridpandas document](https://vgridpandas.gishub.vn).
#
# To work with Vgrid DGGS in QGIS, install the [Vgrid Plugin](https://plugins.qgis.org/plugins/vgridtools/).
#
# To visualize DGGS in Maplibre GL JS, try the [vgrid-maplibre](https://www.npmjs.com/package/vgrid-maplibre) library.
#
# For an interactive demo, visit the [Vgrid Homepage](https://vgrid.vn).

# %% [markdown]
# ### Install vgrid
# Uncomment the following line to install [vgrid](https://pypi.org/project/vgrid/).

# %%
# %pip install vgrid --upgrade

# %% [markdown]
# ### latlon2olc

# %%
from vgrid.conversion.latlon2dggs import latlon2olc

lat = 10.775276
lon = 106.706797
res = 8
olc_id = latlon2olc(lat, lon, res)
olc_id
# Out:
# '7P28QPG4+'

# %% [markdown]
# ### OLC to Polygon

# %%
from vgrid.conversion.dggs2geo.olc2geo  import olc2geo

olc_geo = olc2geo(olc_id)
olc_geo
# Out:
# <POLYGON ((106.705 10.775, 106.708 10.775, 106.708 10.778, 106.705 10.778, 1...>

# %% [markdown]
# ### OLC to GeoJSON

# %%
from vgrid.conversion.dggs2geo.olc2geo import olc2geojson

olc_geojson = olc2geojson(olc_id)
# olc_geojson

# %% [markdown]
# ### Vector to OLC

# %% [markdown]
# #### (Multi)Point to OLC

# %%
from vgrid.conversion.vector2dggs.vector2olc import vector2olc

file_path = "https://raw.githubusercontent.com/opengeoshub/vopendata/main/shape/point.geojson"
point_to_olc = vector2olc(
    file_path,
    # resolution=8,
    topology=True,
    output_format="gpd", verbose=True
)
point_to_olc.plot(edgecolor="white")
# Out:
# Processing features: 100%|██████████| 12/12 [00:00<00:00, 3872.56it/s]
# 12

# %% [markdown]
# #### (Multi)Polygon to OLC

# %%
from vgrid.conversion.vector2dggs.vector2olc import vector2olc

file_path = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/shape/polygon2.geojson"
)
vector_to_olc = vector2olc(file_path, resolution=8, compact=True, depth=-1,
                            predicate = "intersects",output_format="gpd", verbose=True)
# Visualize the output
vector_to_olc.plot(edgecolor="white")
# Out:
# Processing features: 100%|██████████| 1/1 [00:00<00:00, 11.28it/s]
# <Axes: >

# %% [markdown]
# ### OLC Compact

# %%
from vgrid.conversion.dggscompact.olccompact import olccompact

olc_compacted = olccompact(vector_to_olc, olc_id="olc", depth=-1, output_format="gpd", verbose=True)
olc_compacted.plot(edgecolor="white")
# Out:
# <Axes: >

# %% [markdown]
# ### OLC Expand

# %%
from vgrid.conversion.dggscompact.olccompact import olcexpand

olc_expanded = olcexpand(vector_to_olc, resolution=10,  # if set, depth is ignored
    # depth=1,  # 1: children
    output_format="gpd", verbose=True)
olc_expanded.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### OLC Binning

# %%
from vgrid.binning.olcbin import olcbin
import geopandas as gpd
file_path = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/csv/housing.csv"
)
agg = "max"
numeric_col="median_house_value"

olc_bin =  olcbin(file_path, resolution=4, agg=agg, 
                 numeric_col=numeric_col,
                # category_col="category",
                output_format="gpd", verbose=True)
olc_bin.plot(
    column= f"{numeric_col}_{agg}",        # numeric column to base the colors on
    cmap='Spectral_r',        # color scheme (matplotlib colormap)
    legend=True,  
    linewidth=0.2          # boundary width (optional)
)
# Out:
# <Axes: >

# %% [markdown]
# ### OLC Resampling

# %%
from vgrid.conversion.dggsresample import dggsresample
olc_resample = dggsresample(
    source_dggs=olc_bin,
    dggs_from="olc",
    dggs_to="a5",
    method = "nearest", # area_weighted, nearest
    predicate="centroid_within",  # centroid_within, intersects
    dggs_col="olc",
    resample_col=f"{numeric_col}_{agg}",  # column on h3_bin with numbers
    fix_antimeridian=None,
    split_antimeridian=False,
    verbose=True,
)
olc_resample.plot(
    column=f"{numeric_col}_{agg}",  # numeric column to base the colors on
    cmap="Spectral_r",  # color scheme (matplotlib colormap)
    legend=True,
    linewidth=0.2,  # boundary width (optional)
)
# Out:
# Generating A5 cells: 100%|██████████| 162/162 [00:00<00:00, 5820.88 cells/s]
# <Axes: >

# %% [markdown]
# ### Raster to OLC

# %% [markdown]
# #### Download and open raster

# %%
from vgrid.utils.io import download_file
import rasterio
from rasterio.plot import show

raster_url = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/raster/rgb.tif"
)
raster_file = download_file(raster_url)
src = rasterio.open(raster_file, 'r')
print(src.meta)
show(src)
# Out:
# rgb.tif already exists. Skip downloading. Set overwrite=True to overwrite.
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 240, 'height': 147, 'count': 3, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(2.6640125000199077e-06, 0.0, 106.708118755,
#        0.0, -2.6640136054383103e-06, 10.812568272)}
# <Axes: >

# %% [markdown]
# #### Convert raster to OLC

# %%
# %pip install folium

# %%
from vgrid.conversion.raster2dggs.raster2olc    import raster2olc

raster_to_olc =  raster2olc(raster_file, 
                            method = "binning", # nearest, binning
                            stats="mean", output_format="gpd", verbose=True)

# Visualize the output
import folium

m = folium.Map(tiles="CartoDB positron", max_zoom=28)

olc_layer = folium.GeoJson(
    raster_to_olc,
    style_function=lambda x: {
        "fillColor": f"rgb({x['properties']['band_1']}, {x['properties']['band_2']}, {x['properties']['band_3']})",
        "fillOpacity": 1,
        "color": "black",
        "weight": 1,
    },
    popup=folium.GeoJsonPopup(
        fields=["olc", "band_1", "band_2", "band_3"],
        aliases=["OLC ID", "Band 1", "Band 2", "Band 3"],
        style="""
            background-color: white;
            border: 2px solid black;
            border-radius: 3px;
            box-shadow: 3px;
        """,
    ),
).add_to(m)

m.fit_bounds(olc_layer.get_bounds())

# Display the map
m
# Out:
# Cell size: 0.08638527081938627 m2
# Nearest OLC resolution determined: 12
# Binning raster blocks to OLC: 100%|██████████| 14/14 [00:00<00:00, 19.23 block/s]
# Converting raster to OLC: 100%|██████████| 6478/6478 [00:00<00:00, 16430.32 cells/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2ae6d4e2a294443d6e30f95d091738f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#
#             background-color: white;
#             border: 2px solid black;
#             border-radius: 3px;
#             box-shadow: 3px;
#
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2ae6d4e2a294443d6e30f95d091738f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2ae6d4e2a294443d6e30f95d091738f = L.map(
#                 &quot;map_b2ae6d4e2a294443d6e30f95d091738f&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32ee92e77012453eee6e6959945e4877 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 28,
#   &quot;maxNativeZoom&quot;: 28,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_32ee92e77012453eee6e6959945e4877.addTo(map_b2ae6d4e2a294443d6e30f95d091738f);
#
#
#         function geo_json_99f3d0c4d16ed8eb2a9b1835bcf0856e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(95.5, 99.5, 108.5)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(117.33333333333333, 125.0, 134.66666666666666)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(116.33333333333333, 126.0, 135.66666666666666)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(127.0, 137.0, 147.0)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(156.0, 162.0, 172.33333333333334)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(161.66666666666666, 165.66666666666666, 176.66666666666666)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(123.33333333333333, 125.33333333333333, 137.33333333333334)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(127.33333333333333, 128.66666666666666, 140.66666666666666)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(96.33333333333333, 94.33333333333333, 107.33333333333333)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(102.0, 90.0, 101.0)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(120.33333333333333, 103.66666666666667, 111.66666666666667)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(131.0, 115.0, 118.0)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(162.6

# %% [markdown]
# ### OLC Generator

# %%
from vgrid.generator.olcgrid import olcgrid

bbox=[106.699007, 10.762811, 106.717674, 10.778649]
# olc_grid = olcgrid(resolution=2,output_format="gpd")
olc_grid = olcgrid(resolution=10,
                    bbox = bbox, 
                    compact = True,
                    output_format="gpd", verbose=True)
olc_grid.plot(edgecolor="white")
# Out:
# <Axes: >

# %% [markdown]
# ### OLC Inspect

# %%
from vgrid.stats.olcstats import olcinspect 
resolution = 4
olc_inspect = olcinspect(resolution, verbose=True)    
olc_inspect.head()
# Out:
# Generating OLC DGGS: 100%|██████████| 64800/64800 [00:07<00:00, 8186.32 cells/s]
#          olc  resolution  center_lat  center_lon  cell_width    cell_height  \
# 0  22220000+           4       -89.5      -179.5         0.0  111693.864914
# 1  22230000+           4       -89.5      -178.5         0.0  111693.864914
# 2  22240000+           4       -89.5      -177.5         0.0  111693.864914
# 3  22250000+           4       -89.5      -176.5         0.0  111693.864914
# 4  22260000+           4       -89.5      -175.5         0.0  111693.864914
#
#       cell_area  cell_perimeter  \
# 0  1.088612e+08   225337.031822
# 1  1.088612e+08   225337.031822
# 2  1.088612e+08   225337.031822
# 3  1.088612e+08   225337.031822
# 4  1.088612e+08   225337.031822
#
#                                             geometry  crossed  norm_area  \
# 0  POLYGON ((-180 -90, -180 -89, -179 -89, -179 -...    False    0.01383
# 1  POLYGON ((-179 -90, -179 -89, -178 -89, -178 -...    False    0.01383
# 2  POLYGON ((-178 -90, -178 -89, -177 -89, -177 -...    False    0.01383
# 3  POLYGON ((-177 -90, -177 -89, -176 -89, -176 -...    False    0.01383
# 4  POLYGON ((-176 -90, -176 -89, -175 -89, -175 -...    False    0.01383
#
#         ipq       zsc  cvh
# 0  0.026941  0.164138  1.0
# 1  0.026941  0.164138  1.0
# 2  0.026941  0.164138  1.0
# 3  0.026941  0.164138  1.0
# 4  0.026941  0.164138  1.0

# %% [markdown]
# ### OLC Normalized Area Histogram

# %%
from vgrid.stats.olcstats import olc_norm_area_hist
olc_norm_area_hist(olc_inspect)

# %% [markdown]
# ### Distribution of OLC Area Distortions

# %%
from vgrid.stats.olcstats import olc_norm_area
olc_norm_area(olc_inspect)

# %% [markdown]
# ### OLC IPQ Compactness Histogram

# %% [markdown]
# Isoperimetric Inequality (IPQ) Compactness (suggested by [Osserman, 1978](https://sites.math.washington.edu/~toro/Courses/20-21/MSF/osserman.pdf)):
#
# $$C_{IPQ} = \frac{4 \pi A}{p^2}$$
# The range of the IPQ compactness metric is (0,1].
#
# A circle represents the maximum compactness with a value of 1.
#
# As shapes become more irregular or elongated, their compactness decreases toward 0.

# %%
from vgrid.stats.olcstats import olc_compactness_ipq_hist
olc_compactness_ipq_hist(olc_inspect)

# %% [markdown]
# ### Distribution of OLC IPQ Compactness

# %%
from vgrid.stats.olcstats import olc_compactness_ipq
olc_compactness_ipq(olc_inspect)

# %% [markdown]
# ### OLC Convex hull Compactness Histogram:
#
# $$C_{CVH} = \frac{A}{A_{CVH}}$$
#
#
# The range of the convex hull compactness metric is (0,1].
#
# As shapes become more concave, their convex hull compactness decreases toward 0.

# %%
from vgrid.stats.olcstats import olc_compactness_cvh_hist
olc_compactness_cvh_hist(olc_inspect)

# %% [markdown]
# ### Distribution of OLC Convex hull Compactness

# %%
from vgrid.stats.olcstats import olc_compactness_cvh
olc_compactness_cvh(olc_inspect)

# %% [markdown]
# ### OLC Statistics

# %% [markdown]
# Characteristic Length Scale (CLS - suggested by Ralph Kahn): the diameter of a spherical cap of the same cell's area

# %%
from vgrid.stats import olcstats
olcstats()
# Out:
#    resolution       number_of_cells  avg_edge_len_m  avg_cell_area_m2  \
# 0           2                   162    1.774416e+06      3.148553e+12
# 1           4                 64800    8.872082e+04      7.871383e+09
# 2           6              25920000    4.436041e+03      1.967846e+07
# 3           8           10368000000    2.218020e+02      4.919614e+04
# 4          10         4147200000000    1.109010e+01      1.229904e+02
# 5          11        82944000000000    2.479822e+00      6.149518e+00
# 6          12      1658880000000000    5.545051e-01      3.074759e-01
# 7          13     33177600000000000    1.239911e-01      1.537380e-02
# 8          14    663552000000000000    2.772525e-02      7.686898e-04
# 9          15  13271040000000000000    6.199555e-03      3.843449e-05
#
#           cls_m
# 0  2.004280e+06
# 1  1.001110e+05
# 2  5.005536e+03
# 3  2.502768e+02
# 4  1.251384e+01
# 5  2.798180e+00
# 6  6.256920e-01
# 7  1.399090e-01
# 8  3.128460e-02
# 9  6.995449e-03
