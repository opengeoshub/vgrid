# %% [markdown]
# ## Working with GARS in Vgrid DGGS
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeoshub/vgrid/blob/main/docs/notebooks/18_gars.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeoshub/vgrid/HEAD?filepath=docs/notebooks/18_gars.ipynb)
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeoshub/vgrid/blob/main/docs/notebooks/18_gars.ipynb)
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://jupyterlite.gishub.vn/lab/index.html?path=notebooks/vgrid/18_gars.ipynb)
#
# Full Vgrid DGGS documentation is available at [vgrid document](https://vgrid.gishub.vn).
#
# To work with Vgrid DGGS directly in GeoPandas and Pandas, please use [vgridpandas](https://pypi.org/project/vgridpandas/). Full Vgridpandas DGGS documentation is available at [vgridpandas document](https://vgridpandas.gishub.vn).
#
# To work with Vgrid DGGS in QGIS, install the [Vgrid Plugin](https://plugins.qgis.org/plugins/vgridtools/).
#
# To visualize DGGS in Maplibre GL JS, try the [vgrid-maplibre](https://www.npmjs.com/package/vgrid-maplibre) library.
#
# For an interactive demo, visit the [Vgrid Homepage](https://vgrid.vn).

# %% [markdown]
# ### Install vgrid
# Uncomment the following line to install [vgrid](https://pypi.org/project/vgrid/).

# %%
# %pip install vgrid --upgrade

# %% [markdown]
# ### latlon2gars

# %%
from vgrid.conversion.latlon2dggs import latlon2gars

lat = 10.775276
lon = 106.706797
res = 3
gars_id = latlon2gars(lat, lon, res)
gars_id
# Out:
# '574JK19'

# %% [markdown]
# ### GARS to Polygon

# %% [markdown]
# #### (Multi)Point to GARS

# %%
from vgrid.conversion.vector2dggs.vector2gars import vector2gars

file_path = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/shape/point.geojson"
)
point_to_gars = vector2gars(
    file_path,
    # resolution=4,
    topology=True,
    output_format="gpd",
)
point_to_gars.plot(edgecolor="white")
# Out:
# Processing features: 100%|██████████| 12/12 [00:00<00:00, 4490.29it/s]
# <Axes: >

# %% [markdown]
# #### (Multi)Polygon to GARS

# %%
from vgrid.conversion.dggs2geo.gars2geo import gars2geo

gars_geo = gars2geo(gars_id)
gars_geo
# Out:
# <POLYGON ((106.75 10.75, 106.75 10.833, 106.667 10.833, 106.667 10.75, 106.7...>

# %% [markdown]
# ### GARS to GeoJSON

# %%
from vgrid.conversion.dggs2geo.gars2geo import gars2geojson

gars_geojson = gars2geojson(gars_id)
# gars_geojson

# %% [markdown]
# ### Vector to GARS

# %% [markdown]
# #### (Multi)Point to GARS

# %%
from vgrid.conversion.vector2dggs.vector2gars import vector2gars

file_path = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/shape/point2.geojson"
)
point_to_gars = vector2gars(
    file_path,
    # resolution=2,
    topology=True,
    output_format="gpd",
)
point_to_gars.plot()
# Out:
# Processing features: 100%|██████████| 12/12 [00:00<00:00, 1782.91it/s]
# <Axes: >

# %% [markdown]
# #### (Multi)Polygon to GARS

# %%
from vgrid.conversion.vector2dggs.vector2gars import vector2gars

file_path = "https://raw.githubusercontent.com/opengeoshub/vopendata/main/shape/india_polygon.geojson"
vector_to_gars = vector2gars(
    file_path,
    resolution=4,
    compact=False,
    predicate="intersects",
    output_format="gpd",
)
# Visualize the output
# vector_to_georef
vector_to_gars.plot(edgecolor="white")
# Out:
# d:\Github\vgrid\.venv\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: driver GeoJSON does not support open option COMPACT
#   return ogr_read(
# Processing features: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# <Axes: >

# %% [markdown]
# ### GARS Binning

# %%
from vgrid.binning.garsbin import garsbin

file_path = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/csv/housing.csv"
)
stats = "max"
gars_bin = garsbin(
    file_path,
    resolution=2,
    stats=stats,
    numeric_col="median_house_value",
    # category_col="category",
    output_format="gpd",
)
gars_bin.plot(
    column=stats,  # numeric column to base the colors on
    cmap="Spectral_r",  # color scheme (matplotlib colormap)
    legend=True,
    linewidth=0.2,  # boundary width (optional)
)
# Out:
# Generating GARS DGGS: 100%|██████████| 1558/1558 [00:00<00:00, 4715.50 cells/s]
# <Axes: >

# %% [markdown]
# ### Raster to GARS

# %% [markdown]
# #### Download and open raster

# %%
from vgrid.utils.io import download_file
import rasterio
from rasterio.plot import show

raster_url = (
    "https://raw.githubusercontent.com/opengeoshub/vopendata/main/raster/rgb.tif"
)
raster_file = download_file(raster_url)
src = rasterio.open(raster_file, "r")
print(src.meta)
show(src)
# Out:
# Downloading...
# From: https://raw.githubusercontent.com/opengeoshub/vopendata/main/raster/rgb.tif
# To: d:\Github\vgrid\docs\notebooks\rgb.tif
# 100%|██████████| 106k/106k [00:00<00:00, 1.50MB/s]
# {'driver': 'GTiff', 'dtype': 'uint8', 'nodata': None, 'width': 240, 'height': 147, 'count': 3, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(2.6640125000199077e-06, 0.0, 106.708118755,
#        0.0, -2.6640136054383103e-06, 10.812568272)}
# <Axes: >

# %% [markdown]
# #### Convert raster to GARS

# %%
# %pip install folium

# %%
from vgrid.conversion.raster2dggs.raster2gars import raster2gars

raster_to_gars = raster2gars(
    raster_file, resolution=1, stats="mean", output_format="gpd"
)

# Visualize the output
import folium

m = folium.Map(tiles="CartoDB positron", max_zoom=28)

gars_layer = folium.GeoJson(
    raster_to_gars,
    style_function=lambda x: {
        "fillColor": f"rgb({x['properties']['band_1']}, {x['properties']['band_2']}, {x['properties']['band_3']})",
        "fillOpacity": 1,
        "color": "black",
        "weight": 1,
    },
    popup=folium.GeoJsonPopup(
        fields=["gars", "band_1", "band_2", "band_3"],
        aliases=["GARS ID", "Band 1", "Band 2", "Band 3"],
        style="""
            background-color: white;
            border: 2px solid black;
            border-radius: 3px;
            box-shadow: 3px;
        """,
    ),
).add_to(m)

m.fit_bounds(gars_layer.get_bounds())

# Display the map
m
# Out:
# Method: binning
# Stats: mean
# Binning raster blocks to GARS: 100%|██████████| 14/14 [00:00<00:00, 20.63 block/s]
# Converting raster to GARS: 100%|██████████| 1/1 [00:00<00:00, 90.11 cells/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5190fa840a6e5e3787e74350f5647f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#
#             background-color: white;
#             border: 2px solid black;
#             border-radius: 3px;
#             box-shadow: 3px;
#
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5190fa840a6e5e3787e74350f5647f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5190fa840a6e5e3787e74350f5647f7 = L.map(
#                 &quot;map_d5190fa840a6e5e3787e74350f5647f7&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f23c073a9bc1b408ea9a0f36b9664965 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 28,
#   &quot;maxNativeZoom&quot;: 28,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f23c073a9bc1b408ea9a0f36b9664965.addTo(map_d5190fa840a6e5e3787e74350f5647f7);
#
#
#         function geo_json_0c554759c2362bd894c717dbf66df1b3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;rgb(117.20714285714286, 115.10076530612245, 119.53409863945578)&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0c554759c2362bd894c717dbf66df1b3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0c554759c2362bd894c717dbf66df1b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_0c554759c2362bd894c717dbf66df1b3_onEachFeature,
#
#                 style: geo_json_0c554759c2362bd894c717dbf66df1b3_styler,
#             ...{
# }
#         });
#
#         function geo_json_0c554759c2362bd894c717dbf66df1b3_add (data) {
#             geo_json_0c554759c2362bd894c717dbf66df1b3
#                 .addData(data);
#         }
#             geo_json_0c554759c2362bd894c717dbf66df1b3_add({&quot;bbox&quot;: [106.5, 10.5, 107.0, 11.0], &quot;features&quot;: [{&quot;bbox&quot;: [106.5, 10.5, 107.0, 11.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[107.0, 10.5], [107.0, 11.0], [106.5, 11.0], [106.5, 10.5], [107.0, 10.5]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;band_1&quot;: 117.20714285714286, &quot;band_2&quot;: 115.10076530612245, &quot;band_3&quot;: 119.53409863945578, &quot;gars&quot;: &quot;574JK&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_0c554759c2362bd894c717dbf66df1b3.bindPopup(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature =&gt; {
#         if (feature === null) {
#             return &#x27;&#x27;;
#         } else if (typeof(feature)==&#x27;object&#x27;) {
#             return JSON.stringify(feature);
#         } else {
#             return feature;
#         }
#     }
#     let fields = [&quot;gars&quot;, &quot;band_1&quot;, &quot;band_2&quot;, &quot;band_3&quot;];
#     let aliases = [&quot;GARS ID&quot;, &quot;Band 1&quot;, &quot;Band 2&quot;, &quot;Band 3&quot;];
#     let table = &#x27;&lt;table&gt;&#x27; +
#         String(
#         fields.map(
#         (v,i)=&gt;
#         `&lt;tr&gt;
#             &lt;th&gt;${aliases[i].toLocaleString()}&lt;/th&gt;
#
#             &lt;td&gt;${handleObject(layer.feature.properties[v]).toLocaleString()}&lt;/td&gt;
#         &lt;/tr&gt;`).join(&#x27;&#x27;))
#     +&#x27;&lt;/table&gt;&#x27;;
#     div.innerHTML=table;
#
#     return div
#     }
#     ,{
#   &quot;className&quot;: &quot;foliumpopup&quot;,
# });
#
#
#             geo_json_0c554759c2362bd894c717dbf66df1b3.addTo(map_d5190fa840a6e5e3787e74350f5647f7);
#
#
#             map_d5190fa840a6e5e3787e74350f5647f7.fitBounds(
#                 [[10.5, 106.5], [11.0, 107.0]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none

# %% [markdown]
# ### GARS Generator

# %%
from vgrid.generator.garsgrid import garsgrid

gars_grid = garsgrid(
    resolution=4,
    bbox=[106.50410038, 10.68281767, 106.88230310, 10.82281670],
    output_format="geoparquet",
)
# gars_grid.plot(edgecolor="white")
# Out:
# Generating GARS DGGS: 100%|██████████| 207/207 [00:00<00:00, 4712.42 cells/s]
# Output file saved as: d:\Github\vgrid\docs\notebooks\gars_grid_4.parquet

# %% [markdown]
# ### GARS Inspect

# %%
from vgrid.stats.garsstats import garsinspect

resolution = 1
gars_inspect = garsinspect(resolution)
gars_inspect.head()
# Out:
# Generating GARS DGGS: 100%|██████████| 259200/259200 [00:29<00:00, 8664.08 cells/s]
#     gars  resolution  center_lat  center_lon   cell_width   cell_height  \
# 0  001AA           1      -89.75     -179.75     0.000000  55846.975448
# 1  001AB           1      -89.25     -179.75   487.349067  55846.889466
# 2  001AC           1      -88.75     -179.75   974.660272  55846.717528
# 3  001AD           1      -88.25     -179.75  1461.895753  55846.459688
# 4  001AE           1      -87.75     -179.75  1949.017659  55846.116027
#
#       cell_area  cell_perimeter  \
# 0  1.360844e+07   112181.299964
# 1  4.082421e+07   113155.788271
# 2  6.803661e+07   114129.991081
# 3  9.524342e+07   115103.832790
# 4  1.224424e+08   116077.237862
#
#                                             geometry  crossed  norm_area  \
# 0  POLYGON ((-179.5 -90, -179.5 -89.5, -180 -89.5...    False   0.006915
# 1  POLYGON ((-179.5 -89.5, -179.5 -89, -180 -89, ...    False   0.020746
# 2  POLYGON ((-179.5 -89, -179.5 -88.5, -180 -88.5...    False   0.034574
# 3  POLYGON ((-179.5 -88.5, -179.5 -88, -180 -88, ...    False   0.048400
# 4  POLYGON ((-179.5 -88, -179.5 -87.5, -180 -87.5...    False   0.062222
#
#         ipq       zsc  cvh
# 0  0.013589  0.116571  1.0
# 1  0.040066  0.200164  1.0
# 2  0.065638  0.256198  1.0
# 3  0.090337  0.300561  1.0
# 4  0.114195  0.337928  1.0

# %% [markdown]
# ### GARS Normalized Area Histogram

# %%
from vgrid.stats.garsstats import gars_norm_area_hist

gars_norm_area_hist(gars_inspect)

# %% [markdown]
# ### Distribution of GARS Area Distortions

# %%
from vgrid.stats.garsstats import gars_norm_area

gars_norm_area(gars_inspect)

# %% [markdown]
# ### GARS IPQ Compactness Histogram

# %% [markdown]
# Isoperimetric Inequality (IPQ) Compactness (suggested by [Osserman, 1978](https://sites.math.washington.edu/~toro/Courses/20-21/MSF/osserman.pdf)):
#
# $$C_{IPQ} = \frac{4 \pi A}{p^2}$$
# The range of the IPQ compactness metric is (0,1].
#
# A circle represents the maximum compactness with a value of 1.
#
# As shapes become more irregular or elongated, their compactness decreases toward 0.

# %%
from vgrid.stats.garsstats import gars_compactness_ipq_hist

gars_compactness_ipq_hist(gars_inspect)

# %% [markdown]
# ### Distribution of GARS IPQ Compactness

# %%
from vgrid.stats.garsstats import gars_compactness_ipq

gars_compactness_ipq(gars_inspect)

# %% [markdown]
# ### GARS Convex hull Compactness Histogram:
#
# $$C_{CVH} = \frac{A}{A_{CVH}}$$
#
#
# The range of the convex hull compactness metric is (0,1].
#
# As shapes become more concave, their convex hull compactness decreases toward 0.

# %%
from vgrid.stats.garsstats import gars_compactness_cvh_hist

gars_compactness_cvh_hist(gars_inspect)

# %% [markdown]
# ### Distribution of GARS Convex hull Compactness

# %%
from vgrid.stats.garsstats import gars_compactness_cvh

gars_compactness_cvh(gars_inspect)

# %% [markdown]
# ### GARS Statistics

# %% [markdown]
# Characteristic Length Scale (CLS - suggested by Ralph Kahn): the diameter of a spherical cap of the same cell's area

# %%
from vgrid.stats import garsstats

garsstats("km")
# Out:
#    resolution  number_of_cells  avg_edge_len_km  avg_cell_area_km2     cls_km
# 0           1           259200        44.360408        1967.845763  50.055392
# 1           2          1036800        22.180204         491.961441  25.027684
# 2           3          9331200         7.393401          54.662382   8.342560
# 3           4        233280000         1.478680           2.186495   1.668512
