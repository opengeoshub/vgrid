# %% [markdown]
# # dggsinspect in Vgrid DGGS
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeoshub/vgrid/blob/main/docs/notebooks/20_dggsinspect.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeoshub/vgrid/HEAD?filepath=docs/notebooks/20_dggsinspect.ipynb)
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeoshub/vgrid/blob/main/docs/notebooks/20_dggsinspect.ipynb)
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://jupyterlite.gishub.vn/lab/index.html?path=notebooks/vgrid/20_dggsinspect.ipynb)
#
# Full Vgrid DGGS documentation is available at [vgrid document](https://vgrid.gishub.vn).
#
# To work with Vgrid DGGS directly in GeoPandas and Pandas, please use [vgridpandas](https://pypi.org/project/vgridpandas/). Full Vgridpandas DGGS documentation is available at [vgridpandas document](https://vgridpandas.gishub.vn).
#
# To work with Vgrid DGGS in QGIS, install the [Vgrid Plugin](https://plugins.qgis.org/plugins/vgridtools/).
#
# To visualize DGGS in Maplibre GL JS, try the [vgrid-maplibre](https://www.npmjs.com/package/vgrid-maplibre) library.
#
# For an interactive demo, visit the [Vgrid Homepage](https://vgrid.vn).

# %% [markdown]
# ### Install vgrid
# Uncomment the following line to install [vgrid](https://pypi.org/project/vgrid/).

# %%
# %pip install vgrid --upgrade

# %% [markdown]
# ### DGGS Inspect

# %%
from vgrid.stats.dggsstats import dggsinspect
dggsinspect()

# %% [markdown]
# ### DGGS box plot

# %%
from vgrid.stats.dggsstats import dggsboxplot

dggs_parquet_folder = "../../data/a5_paper"
dggsboxplot(dggs_parquet_folder, y_column="ipq", x_rotation=0)
# Out:
# Found 8 parquet files in ../../data/a5_paper
# Loaded ../../data/a5_paper\a5.parquet with 326541 cells
# Loaded ../../data/a5_paper\h3.parquet with 334263 cells
# Loaded ../../data/a5_paper\healpix.parquet with 261828 cells
# Loaded ../../data/a5_paper\igeo7.parquet with 195318 cells
# Loaded ../../data/a5_paper\ivea3h.parquet with 294101 cells
# Loaded ../../data/a5_paper\ivea4r.parquet with 217600 cells
# Loaded ../../data/a5_paper\rhealpix.parquet with 398146 cells
# Loaded ../../data/a5_paper\s2.parquet with 523233 cells
# Loaded data with 2551030 cells across DGGS types: ['A5' 'H3' 'HEALPix' 'IGEO7' 'IVEA3H' 'IVEA4R' 'rHEALPix' 'S2']
# Resolution range: 2-9
# ipq max: 0.9432821790836062
# ipq min: 0.5889735070414063
# Boxplot created successfully!
# Data contains 2551030 cells across DGGS types: ['A5' 'H3' 'HEALPix' 'IGEO7' 'IVEA3H' 'IVEA4R' 'rHEALPix' 'S2']
# Resolution range: 2-9
# ipq max: 0.9432821790836062
# ipq min: 0.5889735070414063
#
# Summary statistics by DGGS type:
#             count      mean       std       max       min   max_min
# dggs_type
# A5         326541  0.745667  0.009879  0.772934  0.716249  1.079142
# H3         334263  0.904669  0.003024  0.939364  0.864794  1.086228
# HEALPix    261828  0.747134  0.048341  0.798688  0.589158  1.355644
# IGEO7      195318  0.896583  0.006965  0.936281  0.832306  1.124923
# IVEA3H     294101  0.899902  0.002636  0.943282  0.893948  1.055187
# IVEA4R     217600  0.676486  0.034011  0.737504  0.609898  1.209225
# S2         523233  0.767255  0.017966  0.803402  0.679841  1.181749
# rHEALPix   398146  0.753343  0.048847  0.786478  0.588974  1.335337
# Saved summary to: dggs_ipq_box.csv
#             count      mean       std       max       min   max_min
# dggs_type
# A5         326541  0.745667  0.009879  0.772934  0.716249  1.079142
# H3         334263  0.904669  0.003024  0.939364  0.864794  1.086228
# HEALPix    261828  0.747134  0.048341  0.798688  0.589158  1.355644
# IGEO7      195318  0.896583  0.006965  0.936281  0.832306  1.124923
# IVEA3H     294101  0.899902  0.002636  0.943282  0.893948  1.055187
# IVEA4R     217600  0.676486  0.034011  0.737504  0.609898  1.209225
# S2         523233  0.767255  0.017966  0.803402  0.679841  1.181749
# rHEALPix   398146  0.753343  0.048847  0.786478  0.588974  1.335337

# %% [markdown]
# ### DGGS distribution

# %%
from vgrid.stats.dggsstats import dggs_distribution
dggs_parquet_folder = "../../data/dggs_paper"
dggs_distribution(dggs_parquet_folder, y_column="norm_area", col_num=2)
# Out:
# Found 4 parquet files in ../../data/dggs_paper
# a5.parquet res=7: 245229 cells  norm_area min=1.0000 max=1.0000
# dggal_healpix.parquet res=7: 196480 cells  norm_area min=0.9999 max=1.0000
# dggrid_igeo7.parquet res=5: 167634 cells  norm_area min=0.8295 max=1.0090
# h3.parquet res=4: 287525 cells  norm_area min=0.5042 max=1.2163
# Saved: d:\Github\vgrid\docs\notebooks\dggs_norm_area_distribution.png
# 'dggs_norm_area_distribution.png'
